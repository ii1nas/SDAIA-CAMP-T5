# %% [markdown]
# # Deep Learning Artificial Neural Network (ANN) Exam question
#
# ## Problem Statement
#
# In this task, you are presented with a dataset containing several features to predict a binary outcome: whether a customer will exit. The dataset contains aspects of customer behavior and demographic information, with the targeted outcome specified in the `Exited` column. Your goal is to develop an Artificial Neural Network (ANN) that can effectively predict this outcome. The model should be trained using the provided data, with a strong focus on tuning and optimizing to achieve high accuracy. The performance of your ANN will be critically evaluated based on its predictive accuracy and the precision of its classifications.

# %% [markdown]
# ### Step 1: Data Exploration
# - Load the dataset provided and display the first few rows to understand the structure and the type of data.
# - Check for missing values and outliers.

# %% [markdown]
# ### Step 2: Data Preprocessing
# - Perform any necessary preprocessing steps including normalization, encoding, and splitting the data into training and test sets.

# %% [markdown]
# ### Step 3: Visualization (optional)
# - Visualize the relationships between features using plots such as histograms, scatter plots, and correlation matrices.

# %% [markdown]
# ### Step 4: Model Design
# - Define an ANN model.
# - Use appropriate activation functions for the hidden layers and the output layer.

# %% [markdown]
# ### Step 5: Model Compilation
# - Choose a suitable optimizer. Explain your choice.
# - Select an appropriate loss function. Explain why this loss function is optimal for your model.
# - Compile your ANN model.

# %% [markdown]
# ### Step 6: Model Training
# - Train your model on the training data. Set appropriate values for the number of epochs and batch size.
# - Ensure to include validation data.

# %% [markdown]
# ### Step 7: Model Evaluation
# - Use the test set and cross-validation to evaluate your model's performance comprehensively.
# - Display the confusion matrix and calculate the accuracy of your model.
# - Discuss the results and any potential areas for improvement.
