# %% [markdown]
# #Kaggle competition by Tuwaiq Academy
# #Task 5 |week 5

# %% [markdown]
# #1- Competition Registration:
# a. Register for the competition on the Kaggle
# platform if you haven't already done so.
#
# b. Access the competition page using the provided link.
#
# c. Create your Team of 3 and give your team a name under KSA vision 2030. Ex: Tuwaiq,
# Hemah… etc

# %% [markdown]
# #mulhum | مُلهم       teem
# #Names of trainees:Safa nasser, lujain, Anwar

# %% [markdown]
# #2- Data Exploration and Preprocessing:
# a. Download the competition datasets provided on the Kaggle competition page.
#
# b. Explore the datasets to understand the features and target variables.
#
# c. Perform data preprocessing tasks such as handling missing values, encoding
# categorical variables, and scaling numerical features.

# %% [markdown]
# *  Introduction
#
#
#
# In an increasingly competitive world, the need for elite training programs is more important than ever. These programs aim to discover and develop exceptional talent, supporting them to achieve their full potential and make a positive impact in their fields. We are pleased to offer you the opportunity to participate in the Kaggle competition entitled “Unlocking the Potential of Elite Training Programs”. This competition aims to provide a platform for trainees in elite programs to test their skills and gain practical experience in the field of machine learning using the famous Kaggle platform.

# %%
#Import library
import pandas as pd
import numpy as np
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score

# %%
pip install colorama

# %% [markdown]
#  **a.  Download the competition datasets provided on the Kaggle competition page.**

# %% [markdown]
# First, we'll load the data from the files you've uploaded using the pandas library, which is a powerful tool in Python for data manipulation and analysis

# %%
test_data = pd.read_csv('test.csv')
train_data = pd.read_csv('train.csv')

# %% [markdown]
# **b.  Explore the datasets to understand the features and target variables.**

# %%
print(train_data.shape[0])
print(test_data.shape[0])
# Out:
# 6548
# 818

# %% [markdown]
# *   display Type data

# %%
from tabulate import tabulate
from termcolor import colored
from colorama import Fore, Back, Style, init
# استخراج أنواع البيانات
train_dtypes = train_data.dtypes
test_dtypes = test_data.dtypes

# إنشاء DataFrame لعرض البيانات
data_types_df = pd.DataFrame({
    'Train Data Types': train_dtypes,
    'Test Data Types': test_dtypes
})

table = tabulate(data_types_df, headers='keys', tablefmt='grid')

# طباعة الجدول بألوان محددة
colored_table = table.replace('-', Fore.BLUE + '-')
print(colored_table)
# Out:
# +--------------------------------+--------------------+-------------------+
# |                                | Train Data Types   | Test Data Types   |
# +================================+====================+===================+
# | Age                            | float64            | float64           |
# +--------------------------------+--------------------+-------------------+
# | College                        | object             | object            |
# +--------------------------------+--------------------+-------------------+
# | Completed Degree               | object             | object            |
# +--------------------------------+--------------------+-------------------+
# | Education Speaciality          | object             | object            |
# +--------------------------------+--------------------+-------------------+
# | Employment Status              | object             | object            |
# ...

# %% [markdown]
# Identifying Numerical and Categorical Columns
#
# After loading the data, we need to identify which columns are numerical and which are categorical. This is crucial because it determines how we'll process these columns moving forward

# %%
numerical_cols = train_data.select_dtypes(include=['int64', 'float64']).columns.tolist()
categorical_cols = train_data.select_dtypes(include=['object']).columns.tolist()
numerical_cols = test_data.select_dtypes(include=['int64', 'float64']).columns.tolist()
categorical_cols = test_data.select_dtypes(include=['object']).columns.tolist()

# %% [markdown]
# *  display first 5 student

# %%
train_data.head()
# Out:
#                              Student ID   Age Gender   Home Region  Home City  \
# 0  4f14c50d-162e-4a15-9cf0-ec129c33bcf0  37.0    ذكر  منطقة الرياض     الرياض
# 1  0599d409-876b-41a5-af05-749ef0e77d32  21.0    ذكر    منطقة عسير  خميس مشيط
# 2  38a11c0e-4afc-4261-9c64-e94cc0a272fb  24.0    ذكر  منطقة الرياض     الرياض
# 3  1693e85b-f80e-40ce-846f-395ddcece6d3  23.0    ذكر  منطقة الرياض     الرياض
# 4  98a0e8d0-5f80-4634-afd8-322aa0902863  23.0    ذكر  منطقة الرياض     الرياض
#
#                              Program ID Program Main Category Code  \
# 0  453686d8-4023-4506-b2df-fac8b059ac26                       PCRF
# 1  cc8e4e42-65d5-4fa1-82f9-6c6c2d508b60                       APMR
# 2  e006900d-05a9-4c2b-a36f-0ffb9fce44cd                       APMR
# 3  2ec15f6b-233b-428a-b9f5-e40bc8d14cf9                       TOSL
# 4  d32da0e9-1aed-48c3-992d-a22f9ccc741e                       CAUF
#
#   Program Sub Category Code Technology Type Program Skill Level  ...  \
# ...

# %% [markdown]
# **c.   Perform data preprocessing tasks**

# %% [markdown]
# *   change Type data

# %%
#Change table Train data:
train_data['Program Presentation Method'] = train_data['Program Presentation Method'].replace({'حضوري': 0, 'عن بعد': 1})
train_data['Program Presentation Method'] = train_data['Program Presentation Method'].astype(int)
#train_data['Program Start Date'] = pd.to_datetime(train_data['Program Start Date'])
#train_data['Program End Date'] = pd.to_datetime(train_data['Program End Date'])
train_data['Program Presentation Method'] = train_data['Program Presentation Method'].replace({'حضوري': 0, 'عن بعد': 1})
train_data['Program Presentation Method'] = train_data['Program Presentation Method'].astype(int)
train_data['Education Speaciality'] = train_data['Education Speaciality'].replace({'Product Design':'تصميم المنتج','Business Administration':'إدارة الأعمال','Computer science and engineering':'علوم الكومبيوتر و الهندسة','Human resources':'الموارد البشرية','ENGINEER IN MARINE TECHNOLOGY':'مهندس في التكنولوجيا البحرية','management information system':'نظام إدارة المعلومات','Civil and Environmental engineering':'الهندسة المدنية والبيئية','Computer Networking and Cyber security':'شبكات الكمبيوتر والأمن السيبراني','product design':'تصميم المنتج','Software Engineering':'هندسة البرمجيات','Software engineering':'هندسة البرمجيات','Information technology':'تكنولوجيا المعلومات','Information Technology': 'تكنولوجيا المعلومات','information technology':'تكنولوجيا المعلومات','computer science':'علوم الكمبيوتر','Computer Science':'علوم الكمبيوتر','Information System':'نظام معلومات','Cybersecurity engineering':'هندسة الأمن السيبراني','Cybersecurity':'الأمن الإلكتروني','cybersecurity':'الأمن الإلكتروني','cyber security':'الأمن الإلكتروني','Is':'الأمن السيبراني','Information Security':'أمن المعلومات','Biology': 'الاحياء','Chemistry':'كيمياء','Physics and astronomy':'الفيزياء وعلم الفلك','Computer Network and Communication':'شبكات الكمبيوتر والاتصالات','IT security':'الأمن السيبراني','Art and design':'فن و تصميم','Electrical and Electronics Engineering':'الهندسة الكهربائية والالكترونيات', 'IT': 'تكنولوجيا المعلومات','It':'تكنولوجيا المعلومات','Civil and Environmental engineering':'الهندسة المدنية والبيئية','Software Engineer':'هندسة البرمجيات','Software Engineering' :'هندسة البرمجيات','Software engineering':'هندسة البرمجيات','Software engineering':'هندسة البرمجيات','Computer Networking and Cyber security':'شبكات الكمبيوتر والأمن السيبراني','Computer Network':'شبكة الكمبيوتر','Computer Information Systems':'نظم المعلومات الحاسوبية','Telecommunication and networking engineering':'هندسة الاتصالات والشبكات','Space science':'علم الفضاء','Computer information systems':'نظم المعلومات الحاسوبية','computer information system':'نظم المعلومات الحاسوبية','network security engineering':'هندسة أمن الشبكات','Data Science':'علم البيانات','Long Island University-New York':'جامعة لونغ آيلاند – نيويورك','Civil and Environmental engineering':'الهندسة المدنية والبيئية','BS in Computer Science':'بكالوريوس في علوم الكمبيوتر','Network and communication system':'نظام الشبكة والاتصالات','Computer programming':'برمجة الحاسب الآلي','computer science':'علوم الكمبيوتر','Computer sicence':'علوم الكمبيوتر','Computer Science':'علوم الكمبيوتر','MIS':'نظم المعلومات الإدارية','Arabic NLP':'البرمجة اللغوية العصبية','product design':'تصميم المنتج','Product design':'تصميم المنتج','management information system':'نظام إدارة المعلومات','Construction Management':'إدارة الإنشاءات','applied network systems engineering':'هندسة أنظمة الشبكات التطبيقية','Cybersecurity':'الأمن الإلكتروني','Business Administration':'إدارة الأعمال','E-Businesses':'الأعمال الإلكترونية','CS':'علم الحاسوب','Insurance and Risk management':'التأمين وإدارة المخاطر','Management Information System':'نظام إدارة المعلومات','Cloud computing architect':'مهندس الحوسبة السحابية','Educational Technology':'تكنولوجيا التعليم','Network telecommunication systems':'أنظمة الاتصالات الشبكية','Management information system':'نظام إدارة المعلومات','Information technology':'تكنولوجيا المعلومات','Information Technology':'تكنولوجيا المعلومات','University of Dubuque':'جامعة دوبوك','Applied linguistics':'اللغويات التطبيقية','Information Systems Security':'أمن نظم المعلومات','Information Systems':'نظم المعلومات','Information System':'نظم المعلومات','information system':'نظم المعلومات','Health informatics':'المعلوماتية الصحية','information systems':'نظم المعلومات','English':'إنجليزي','English language':'إنجليزي','Management':'إدارة','Businesses IT':'تكنولوجيا المعلومات للشركات','Computer Engineering':'هندسة الكمبيوتر','Software engineer':'مهندس برمجيات','Management Information Systems':'نظم المعلومات الإدارية','Computer science':'علوم الكمبيوتر','computer sicence':'علوم الكمبيوتر','Information system':'نظام معلومات','علوم الحاسب - Computer Science':'علوم الحاسب','computer sciences':'علوم الكمبيوتر','Data science':'علم البيانات','Cyber forensics and information system':'الطب الشرعي السيبراني ونظام المعلومات','business management':'ادارة اعمال','Industrial Engineer Technology':'تكنولوجيا المهندس الصناعي','Cyber security':'الأمن الإلكتروني','Information technology cybersecurity track':'مسار الأمن السيبراني لتكنولوجيا المعلومات','Computer and Information technology':'الكمبيوتر وتكنولوجيا المعلومات','Network':'شبكة','Mechanical engineer technology':'تكنولوجيا مهندس ميكانيكي','computer seince':'علوم الكمبيوتر','MBA':'إدارة الأعمال','Computer Systems Engineering':'هندسة أنظمة الحاسوب','electrical engineering':'الهندسة الكهربائية','Computer science and information':'علوم الحاسوب والمعلومات','artificial intelligence':'الذكاء الاصطناعي','Electronics and Control specialization':'الكترونيات وتحكم','Beauty':'جمال','Information system computing':'حوسبة نظام المعلومات','Computer Networks':'شبكات الحاسب','Information systems':'نظم المعلومات','Cyber Security':'الأمن الإلكتروني','computer Science':'علوم الكمبيوتر','Communication and computer networks':'شبكات الاتصالات والكمبيوتر','Networks support system':'نظام دعم الشبكات','Computer engineering':'هندسة الكمبيوتر','Electronics Engineering Technology':'تكنولوجيا هندسة الإلكترونيات','COMPUTER PROGRAMMING':'برمجة الحاسب الآلي','Cybersecurity Engineering':'هندسة الأمن السيبراني','Information Technologies':'تقنيات المعلومات','Information technology - cybersecurity':'الأمن السيبراني','Computer engineering':'هندسة الكمبيوتر','Computer Security':'حماية الحاسوب','Computer Scince':'علوم الكمبيوتر','computer scince':'علوم الكمبيوتر','quantum computing':'الاحصاء الكمية','Computer Since':'علوم الكمبيوتر','Management Information system':'نظام إدارة المعلومات','Computer engineer':'مهندس كمبيوتر','Information systems with concentration in cyber security Management and information Assurance':'نظم المعلومات','Artificial Intelligence':'الذكاء الاصطناعي','Radiology Technologist':'فني الأشعة','Health Information Systems':'نظم المعلومات الصحية','Programming':'مبرمج','Softeare Engineering':'هندسة البرمجيات','Information System (Decision Support System)':'نظام المعلومات (نظام دعم القرار)','Public relations':'العلاقات العامة','It cyber security track':'الأمن السيبراني','INTER-IoT':'إنتر-إنترنت الأشياء','Computer science software engineering':'هندسة البرمجيات علوم الحاسوب','mis':'نظم المعلومات الإدارية','respiratory care':'الرعاية التنفسية','computer engineer':'مهندس كمبيوتر','Computer information system':'نظام المعلومات الحاسوبية','Computer of engineering':'الكمبيوتر الهندسي','Information security':'أمن المعلومات',
                                                                                  'Computer Science and Engineering':'علوم الكومبيوتر و الهندسة','art education':'التربية الفنية','Dental surgery':'جراحة الأسنان','libraries and Information':'المكتبات والمعلومات','Data Management':'إدارة البيانات','software engineer':'مهندس برمجيات','Health Informatics':'المعلوماتية الصحية','Management Information Systmes':'نظم المعلومات الإدارية','PMP':' محترف إدارة المشاريع','language and translation':'اللغة والترجمة','BSc Geology':'جيولوجيا','EMBA':'ماجستير إدارة الأعمال التنفيذي','E-Business':'الأعمال الإلكترونية','Mobile communication and security':'الاتصالات المتنقلة والأمن','Actuarial Science':'علم التخمين','Information Tehnology':'تكنولوجيا المعلومات','Information Analytics':'تحليلات المعلومات','Graphic Design & Digital Media':'التصميم الجرافيكي والوسائط الرقمية','computer security':'حماية الحاسوب','Advanced security and digital forensic':'الأمن المتقدم والطب الشرعي الرقمي','Information technology &amp; computing':'تكنولوجيا المعلومات والحوسبة','Statistics':'إحصائيات','COMPUTER ENGINEER':'مهندس كمبيوتر','Mathematical':'رياضيات','Mathematics':'رياضيات','Applied Computing-Computer Networks Track':'مسار الحاسبات التطبيقية-شبكات الحاسب','Electrical Engineering':'الهندسة الكهربائية','IS':'الأمن السيبراني','Products design':'تصميم المنتجات','Applied computing cyber security track':'مسار الحوسبة التطبيقية للأمن السيبراني','Computer':'حاسوب','Multimedia':'الوسائط المتعددة','Computer sciences':'علوم الحاسوب','Engineering Management':'الإدارة الهندسية','information System':'نظام معلومات','Networking and telecommunication system':'نظام الشبكات والاتصالات السلكية واللاسلكية','Masters in Business Administration':'درجة الماجستير في إدارة الأعمال','Health Information Management and Technology':'إدارة وتكنولوجيا المعلومات الصحية','Cyber forensics and information security':'الطب الشرعي السيبراني وأمن المعلومات','Human resources management':'إدارة الموارد البشرية','Physics':'الفيزياء','Computer Information System ':'نظام المعلومات الحاسوبية','Software system engineering':'هندسة نظم البرمجيات','Computer and information technology':'الكمبيوتر وتكنولوجيا المعلومات','web devolper':'مطور ويب','accounting':'محاسبة','Business':'تجاره','Management information systems':'نظم المعلومات الإدارية','Finance':'تمويل','Computer Engineering Technology':'تكنولوجيا هندسة الحاسوب','Cybersecurity and Info Assurance':'الأمن السيبراني وضمان المعلومات','Computer Engineer':'مهندس كمبيوتر','Electronics and Communication':'الالكترونيات والاتصالات','computer since':'علوم الكمبيوتر','Network Engineering':'هندسة الشبكات','Cyber forensics and information security':'الطب الشرعي السيبراني وأمن المعلومات','Management and Human Resources':'الإدارة والموارد البشرية','Computer networks':'شبكات الحاسب','Mechanical Engieering':'مهندس ميكانيكى','Software Development':'تطوير البرمجيات','English Literature':'أدب إنجليزي','Nutrition':'Nutrition','Database and programming':'قاعدة البيانات والبرمجة','Digital media':'وسائل الإعلام الرقمية','هندسة كهربائية الكترونيات / Electrical Engineering':'هندسة كهربائية الكترونيات ','Information technology IT':'تكنولوجيا المعلومات','Computer Sciences':'علوم الحاسوب','IT management BI':'إدارة تكنولوجيا المعلومات ','Sport management':'إدارة الرياضة','Network  System Engineer':'مهندس نظام الشبكات','Occupational therapy':'علاج بالممارسة','Special education':'التعليم الخاص','Business And Adminstration':'الاعمال و الادارة','Data Analytics':'تحليلات البيانات','telecommunication and network engineer':'مهندس اتصالات وشبكات','Network of computer':'شبكة الكمبيوتر','Computer scientists':'علماء الكمبيوتر','Master of business development MBA (system design software development strategy )':'ماجستير في تطوير الأعمال ماجستير في إدارة الأعمال (استراتيجية تطوير برمجيات تصميم النظام)','Health Education':'التثقيف الصحي','Artifical intellegence':'الذكاء الاصطناعي','Network engineer':'مهندس الشبكة','Applied Mathematics':'الرياضيات التطبيقية','Networking and telecommunications systems':'أنظمة الشبكات والإتصالات','Computer and Information Systems':'الكمبيوتر ونظم المعلومات','Computer science cybersecurity':'علوم الكمبيوتر الأمن السيبراني','English language and literature':'اللغة الإنجليزية وآدابها','English Language and Literature':'اللغة الإنجليزية وآدابها','management information system (MIS)':'نظام المعلومات الإدارية','Islamic students':'طلاب الاسلام','Networks and telecommunications':'الشبكات والإتصالات','Art and Design/public relations':'الفن والتصميم / العلاقات العامة','Visual Computing':'الحوسبة المرئية','Conputer scince':'علوم الكمبيوتر','Industrial and System Engineering':'الهندسة الصناعية والنظم','GIS':'نظام المعلومات الجغرافية','تقنية معلومات information technology':'تقنية معلومات ','Management information systems':'نظم المعلومات الإدارية','IT Cybersecurity':'الأمن السيبراني لتكنولوجيا المعلومات','Information technology and computing':'تكنولوجيا المعلومات والحوسبة','CS  نظم معلومات | Information System':' نظم معلومات ','Computer Information Systym':'نظام المعلومات الحاسوبية','cyberSecurity and Networking':'الأمن السيبراني والشبكات','تصميم منتجات - product design':'تصميم منتجات ','Cs':'علم الكمبيوتر','Information Systems - Cybersecurity':'نظم المعلومات - الأمن السيبراني','(IT) Information Technology':'تكنولوجيا المعلومات','Advanced Computer Science':'علوم الكمبيوتر المتقدمة','Public relation':'العلاقات العامة','IT information technology':'تكنولوجيا المعلومات','IT - Networks and communications':'تكنولوجيا المعلومات - الشبكات والاتصالات','data science':'علم البيانات','MS in Industrial Engineering':'ماجستير في الهندسة الصناعية','Engineering of computer network systems support':'هندسة دعم أنظمة شبكات الكمبيوتر','Information management':'إدارة المعلومات','Cyber forensics and information security':'الطب الشرعي السيبراني وأمن المعلومات','Networking':'الشبكات','Electrical engineer':'مهندس كهرباء','IT:health care informatics':'تكنولوجيا المعلومات: معلوماتية الرعاية الصحية','Information Science':'علم المعلومات','Public administration':'الإدارة العامة','BEng Computer Systems Engineering':'بكالوريوس هندسة أنظمة الكمبيوتر','CIS':'نظم المعلومات الحاسوبية'})
#Change table Test data:
test_data['Program Presentation Method'] = test_data['Program Presentation Method'].replace({'حضوري': 0, 'عن بعد': 1})
test_data['Program Presentation Method'] = test_data['Program Presentation Method'].astype(int)
test_data['Education Speaciality'] = test_data['Education Speaciality'].replace({'Biology': 'الاحياء','Chemistry':'كيمياء','Physics and astronomy':'الفيزياء وعلم الفلك','Computer Network and Communication':'شبكات الكمبيوتر والاتصالات','IT security':'الأمن السيبراني','Art and design':'فن و تصميم','Electrical and Electronics Engineering':'الهندسة الكهربائية والالكترونيات', 'IT': 'تكنولوجيا المعلومات','It':'تكنولوجيا المعلومات','Civil and Environmental engineering':'الهندسة المدنية والبيئية', 'Software Engineering' :'هندسة البرمجيات','Software engineering':'هندسة البرمجيات','Software engineering':'هندسة البرمجيات','Computer Networking and Cyber security':'شبكات الكمبيوتر والأمن السيبراني','Computer Network':'شبكة الكمبيوتر',  'Computer information systems':'نظم المعلومات الحاسوبية','network security engineering':'هندسة أمن الشبكات','Data Science':'علم البيانات','Long Island University-New York':'جامعة لونغ آيلاند – نيويورك','Civil and Environmental engineering':'الهندسة المدنية والبيئية','BS in Computer Science':'بكالوريوس في علوم الكمبيوتر','Network and communication system':'نظام الشبكة والاتصالات','Computer programming':'برمجة الحاسب الآلي','computer science':'علوم الكمبيوتر','Computer sicence':'علوم الكمبيوتر','Computer Science':'علوم الكمبيوتر','MIS':'نظم المعلومات الإدارية','Arabic NLP':'البرمجة اللغوية العصبية','product design':'تصميم المنتج','Product design':'تصميم المنتج','management information system':'نظام إدارة المعلومات','Construction Management':'إدارة الإنشاءات',
                                                                                'applied network systems engineering':'هندسة أنظمة الشبكات التطبيقية','Cybersecurity':'الأمن الإلكتروني','Business Administration':'إدارة الأعمال','E-Businesses':'الأعمال الإلكترونية','CS':'علم الحاسوب','Insurance and Risk management':'التأمين وإدارة المخاطر','Management Information System':'نظام إدارة المعلومات','Cloud computing architect':'مهندس الحوسبة السحابية','Educational Technology':'تكنولوجيا التعليم','Network telecommunication systems':'أنظمة الاتصالات الشبكية','Management information system':'نظام إدارة المعلومات','Information technology':'تكنولوجيا المعلومات','Information Technology':'تكنولوجيا المعلومات','University of Dubuque':'جامعة دوبوك','Applied linguistics':'اللغويات التطبيقية','Information Systems Security':'أمن نظم المعلومات','Information Systems':'نظم المعلومات','Information System':'نظم المعلومات','information systems':'نظم المعلومات','English':'إنجليزي','Management':'إدارة','Businesses IT':'تكنولوجيا المعلومات للشركات','Computer Engineering':'هندسة الكمبيوتر','Software engineer':'مهندس برمجيات','Management Information Systems':'نظم المعلومات الإدارية','Computer science':'علوم الكمبيوتر','computer sicence':'علوم الكمبيوتر','Information system':'نظام معلومات','علوم الحاسب - Computer Science':'علوم الحاسب','computer sciences':'علوم الكمبيوتر','Data science':'علم البيانات',})

# %% [markdown]
# *   handling missing values

# %% [markdown]
# Next, we'll address any missing values in the data. We'll use SimpleImputer from sklearn to fill missing values in numerical columns with the median and categorical columns with the most frequent value

# %%
train_isnull = train_data.isnull().sum()
test_isnull = test_data.isnull().sum()

# إنشاء DataFrame لعرض البيانات
data_isnull = pd.DataFrame({
    'Train Data Null': train_isnull,
    'Test Data Null': test_isnull
})

tableMissing = tabulate(data_isnull , headers='keys', tablefmt='grid')

# طباعة الجدول بألوان محددة
colored_tableM = tableMissing.replace('-', Fore.BLUE + '-')
print(colored_tableM)
# Out:
# +--------------------------------+-------------------+------------------+
# |                                |   Train Data Null |   Test Data Null |
# +================================+===================+==================+
# | Age                            |                92 |               14 |
# +--------------------------------+-------------------+------------------+
# | College                        |              3890 |              492 |
# +--------------------------------+-------------------+------------------+
# | Completed Degree               |                 0 |                0 |
# +--------------------------------+-------------------+------------------+
# | Education Speaciality          |               277 |               37 |
# +--------------------------------+-------------------+------------------+
# | Employment Status              |               566 |               70 |
# +--------------------------------+-------------------+------------------+
# ...

# %%
#handel with train table
'''train_data['Age'].fillna(train_data['Age'].median(), inplace=True)

mode_value = train_data['Level of Education'].mode()[0]
train_data['Level of Education'].fillna(value=mode_value, inplace=True)
mode_valueC = train_data['Home Region'].mode()[0]
train_data['Home City'].fillna(value=mode_value, inplace=True)
mode_valueC = train_data['Education Speaciality'].mode()[0]
train_data['Education Speaciality'].fillna(value=mode_valueC, inplace=True)
train_data['Program Sub Category Code'].fillna(train_data['Program Sub Category Code'].mode(), inplace=True)
train_data['Technology Type'].fillna(train_data['Technology Type'].mode()[0], inplace=True)
train_data['Program Skill Level'].fillna(train_data['Program Skill Level'].mode()[0], inplace=True)
train_data['College'].fillna('Unknown', inplace=True)
train_data['University Degree Score'].fillna(train_data['University Degree Score'].median(), inplace=True)
train_data['University Degree Score System'].fillna(train_data['University Degree Score System'].mode()[0], inplace=True)
train_data['Employment Status'].fillna('Unknown', inplace=True)
train_data['Job Type'].fillna('Unknown', inplace=True)
train_data['Still Working'].fillna('Unknown', inplace=True)
mode_value = train_data['Program Sub Category Code'].mode()[0]
train_data['Program Sub Category Code'].fillna(value=mode_value, inplace=True)
#handel with test table
test_data['Age'].fillna(test_data['Age'].median(), inplace=True)
mode_value = test_data['Home Region'].mode()[0]
test_data['Home Region'].fillna(value=mode_value, inplace=True)
mode_value = test_data['Home Region'].mode()[0]
test_data['Home Region'].fillna(value=mode_value, inplace=True)
mode_valueC = test_data['Home Region'].mode()[0]
test_data['Home City'].fillna(value=mode_valueC, inplace=True)
test_data['Program Sub Category Code'].fillna(test_data['Program Sub Category Code'].mode(), inplace=True)
test_data['Technology Type'].fillna(test_data['Technology Type'].mode()[0], inplace=True)
test_data['Program Skill Level'].fillna(test_data['Program Skill Level'].mode()[0], inplace=True)
test_data['College'].fillna('Unknown', inplace=True)
test_data['University Degree Score'].fillna(test_data['University Degree Score'].median(), inplace=True)
test_data['University Degree Score System'].fillna(test_data['University Degree Score System'].mode()[0], inplace=True)
test_data['Employment Status'].fillna('Unknown', inplace=True)
test_data['Job Type'].fillna('Unknown', inplace=True)
test_data['Still Working'].fillna('Unknown', inplace=True)
test_data['Education Speaciality'].fillna('Unknown', inplace=True)
mode_value = test_data['Level of Education'].mode()[0]
test_data['Level of Education'].fillna(value=mode_value, inplace=True)
mode_value = test_data['Program Sub Category Code'].mode()[0]
test_data['Program Sub Category Code'].fillna(value=mode_value, inplace=True)'''
# Out:
# "train_data['Age'].fillna(train_data['Age'].median(), inplace=True)\n\nmode_value = train_data['Level of Education'].mode()[0]\ntrain_data['Level of Education'].fillna(value=mode_value, inplace=True)\nmode_valueC = train_data['Home Region'].mode()[0]\ntrain_data['Home City'].fillna(value=mode_value, inplace=True)\nmode_valueC = train_data['Education Speaciality'].mode()[0]\ntrain_data['Education Speaciality'].fillna(value=mode_valueC, inplace=True)\ntrain_data['Program Sub Category Code'].fillna(train_data['Program Sub Category Code'].mode(), inplace=True)\ntrain_data['Technology Type'].fillna(train_data['Technology Type'].mode()[0], inplace=True)\ntrain_data['Program Skill Level'].fillna(train_data['Program Skill Level'].mode()[0], inplace=True)\ntrain_data['College'].fillna('Unknown', inplace=True)\ntrain_data['University Degree Score'].fillna(train_data['University Degree Score'].median(), inplace=True)\ntrain_data['University Degree Score System'].fillna(train_data['University De
# ...

# %%
from sklearn.impute import SimpleImputer

# Imputer for numerical data
numerical_imputer = SimpleImputer(strategy='median')
# Imputer for categorical data
categorical_imputer = SimpleImputer(strategy='most_frequent')

# Apply imputation to numerical columns
train_data[numerical_cols] = numerical_imputer.fit_transform(train_data[numerical_cols])
test_data[numerical_cols] = numerical_imputer.transform(test_data[numerical_cols])

# Apply imputation to categorical columns
train_data[categorical_cols] = categorical_imputer.fit_transform(train_data[categorical_cols])
test_data[categorical_cols] = categorical_imputer.transform(test_data[categorical_cols])

# %%
train_isnull = train_data.isnull().sum()
test_isnull = test_data.isnull().sum()

# إنشاء DataFrame لعرض البيانات
data_isnull = pd.DataFrame({
    'Train Data Null': train_isnull,
    'Test Data Null': test_isnull
})

tableMissing = tabulate(data_isnull , headers='keys', tablefmt='grid')

# طباعة الجدول بألوان محددة
colored_tableM = tableMissing.replace('-', Fore.BLUE + '-')
print(colored_tableM)
# Out:
# +--------------------------------+-------------------+------------------+
# |                                |   Train Data Null |   Test Data Null |
# +================================+===================+==================+
# | Age                            |                 0 |                0 |
# +--------------------------------+-------------------+------------------+
# | College                        |                 0 |                0 |
# +--------------------------------+-------------------+------------------+
# | Completed Degree               |                 0 |                0 |
# +--------------------------------+-------------------+------------------+
# | Education Speaciality          |                 0 |                0 |
# +--------------------------------+-------------------+------------------+
# | Employment Status              |                 0 |                0 |
# +--------------------------------+-------------------+------------------+
# ...

# %% [markdown]
# *   Scaling numerical features and encoding categorical variables

# %% [markdown]
# Finally, we'll encode categorical data and scale numerical data to prepare it for modeling

# %%
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.compose import ColumnTransformer

# Set up the data transformer
preprocessor = ColumnTransformer(
    transformers=[
        ('num', StandardScaler(), numerical_cols),
        ('cat', OneHotEncoder(handle_unknown='ignore'), categorical_cols)
    ])

# Apply transformations to the data
train_data_preprocessed = preprocessor.fit_transform(train_data)
test_data_preprocessed = preprocessor.transform(test_data)

# %% [markdown]
# Summary:
#
# Encoding transforms categorical data into a format that is easier for ML models to understand.
#
# Scaling adjusts the range of numerical features so that different scales do not distort the learning process of the model.
#
# Both steps help in enhancing model performance and are crucial for achieving accurate predictions.

# %% [markdown]
# With these steps completed, the data is now ready to be used for building models. This setup ensures that the data fed into the model is clean, well-structured, and appropriate for the algorithms you might want to use

# %% [markdown]
# # **---------------------------------------------------------------------------------------------**

# %% [markdown]
# # 3-Model Building
# a. Split the preprocessed data into training and testing sets.
#
# b. Implement machine learning models to predict student persistence and completion
# rates. You can start with simple models like logistic regression or decision trees.
#
# c. Evaluate the performance of each model using appropriate evaluation metrics such
# as accuracy, precision, recall, or F1-score

# %% [markdown]
# **A.Build Models**
#
# Start by implementing simpler models. Simpler models are easier to interpret and can often provide baseline results quickly.
#
# **Logistic Regression:** Good for binary classification tasks.
#
# **Decision Trees:** Useful for handling nonlinear data with a hierarchical structure of decisions
#
# **Evaluate Models**
#
# To determine the best model, we evaluate them using metrics such as accuracy, precision, recall, and F1-score.
#
# - Accuracy: Measures the overall correctness of the model.
# - Precision: Measures the accuracy of positive predictions.
# - Recall: Measures the model's ability to detect positive samples.
# - F1-Score: Harmonic mean of precision and recall

# %% [markdown]
# *   Split the preprocessed data into training and testing sets.

# %%
X_train = train_data_preprocessed
y_train = train_data["Y"]
X_test = test_data_preprocessed

# %% [markdown]
# *   Implement machine learning models to predict student persistence and completion

# %%
try:
    modelL = LogisticRegression(C=1.0, max_iter=1000)
    modelL.fit(X_train, y_train)
    predictions = modelL.predict(X_test)
    print("The model was trained successfully.")

    scoring = ['accuracy', 'precision', 'recall', 'f1']
    scores = cross_validate(modelL, X_train, y_train, scoring=scoring, cv=5)

    print("Cross-Validation Scores:")
    cv_results = pd.DataFrame(scores)
    table = tabulate(cv_results, headers=['Fit_time', 'Score_time', 'Test_accuracy', 'Test_precision', 'Test_recall', 'Test_f1'], tablefmt='grid')
    colored_tableM = table.replace('-', Fore.BLUE + '-')
    print(colored_tableM)

    avg_accuracy = scores['test_accuracy'].mean()
    avg_f1 = scores['test_f1'].mean()  # Calculate average F1 score
    print("Average test accuracy:", avg_accuracy)
    print("Average F1 score:", avg_f1)

except Exception as e:
    print("Failure to train:", e)
# Out:
# The model was trained successfully.
# Cross-Validation Scores:
# +----+------------+--------------+-----------------+------------------+---------------+-----------+
# |    |   Fit_time |   Score_time |   Test_accuracy |   Test_precision |   Test_recall |   Test_f1 |
# +====+============+==============+=================+==================+===============+===========+
# |  0 |   1.43223  |    0.0257907 |        0.89542  |         0.741497 |      0.524038 |  0.614085 |
# +----+------------+--------------+-----------------+------------------+---------------+-----------+
# |  1 |   0.826078 |    0.0348432 |        0.905344 |         0.7625   |      0.586538 |  0.663043 |
# +----+------------+--------------+-----------------+------------------+---------------+-----------+
# |  2 |   0.844897 |    0.0157795 |        0.885496 |         0.683544 |      0.519231 |  0.590164 |
# +----+------------+--------------+-----------------+------------------+---------------+-----------+
# ...

# %%
try:
    modelT = DecisionTreeClassifier(max_depth=2, random_state=42)

    modelT.fit(X_train, y_train)
    dtree_pred=modelT.predict(X_test)
    print("The model was trained successfully.")
    scoring = ['accuracy', 'precision', 'recall', 'f1']
    scores = cross_validate(modelT, X_train, y_train, scoring=scoring, cv=5)
    print("Cross-Validation Scores:")


    cv_results = pd.DataFrame(scores)
    table = tabulate(cv_results, headers=['Fit_time', 'Score_time', 'Test_accuracy', 'Test_precision', 'Test_recall', 'Test_f1'], tablefmt='grid')
    colored_tableM = table.replace('-', Fore.BLUE + '-')
    print(colored_tableM)
    avg_accuracy = scores['test_accuracy'].mean()
    avg_f1 = scores['test_f1'].mean()  # Calculate average F1 score
    print("Average test accuracy:", avg_accuracy)
    print("Average F1 score:", avg_f1)



except Exception as e:
    print("Failure to train:", e)
# Out:
# The model was trained successfully.
# Cross-Validation Scores:
# +----+------------+--------------+-----------------+------------------+---------------+-----------+
# |    |   Fit_time |   Score_time |   Test_accuracy |   Test_precision |   Test_recall |   Test_f1 |
# +====+============+==============+=================+==================+===============+===========+
# |  0 |  0.207944  |    0.0189064 |        0.893893 |         0.660465 |      0.682692 |  0.671395 |
# +----+------------+--------------+-----------------+------------------+---------------+-----------+
# |  1 |  0.182964  |    0.0284693 |        0.883969 |         0.625    |      0.673077 |  0.648148 |
# +----+------------+--------------+-----------------+------------------+---------------+-----------+
# |  2 |  0.134637  |    0.01314   |        0.861832 |         0.566502 |      0.552885 |  0.559611 |
# +----+------------+--------------+-----------------+------------------+---------------+-----------+
# ...

# %% [markdown]
# # 4- Model Improvement
#
# a. Experiment with different machine learning algorithms and techniques to improve
# model performance.
#
# b. Fine-tune hyperparameters of the selected models to optimize performance.
#
# c. Explore feature engineering techniques to extract more meaningful insights from the
# data.

# %% [markdown]
# **A.Experimenting with Different Algorithms**
#
#
#
# - Random Forest: Provides an improvement over decision trees by reducing the risk of overfitting.
#
# - Support Vector Machines (SVM): Effective for high-dimensional problems.
# - Gradient Boosting: A powerful model that focuses on correcting the errors made by previous estimators
#
# Use GridSearchCV or RandomizedSearchCV to find the optimal set of parameters

# %% [markdown]
# *   Experiment with different machine learning algorithms and techniques to improve  model performance.

# %%
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
# Standardize the data
scaler = StandardScaler(with_mean=False)

X_scaled = scaler.fit_transform(X_train)

# Support Vector Machine
svm_model = SVC(kernel='linear')

# Random Forest
rf_model = RandomForestClassifier(n_estimators=100)

# Gradient Boosting
gb_model = GradientBoostingClassifier(n_estimators=100)

# Evaluate models using cross-validation
svm_scores = cross_val_score(svm_model, X_scaled,y_train, cv=5)
rf_scores = cross_val_score(rf_model, X_scaled, y_train, cv=5)
gb_scores = cross_val_score(gb_model, X_scaled, y_train, cv=5)

print("SVM Accuracy: %0.2f (+/- %0.2f)" % (svm_scores.mean(), svm_scores.std() * 2))
print("Random Forest Accuracy: %0.2f (+/- %0.2f)" % (rf_scores.mean(), rf_scores.std() * 2))
print("Gradient Boosting Accuracy: %0.2f (+/- %0.2f)" % (gb_scores.mean(), gb_scores.std() * 2))
# create Dictionary content all accuracy
model_scores = {'SVM': (svm_scores.mean(), svm_scores.std()),'Random Forest': (rf_scores.mean(), rf_scores.std()) ,'Gradient Boosting': (gb_scores.mean(), gb_scores.std())}
# find max accuracy
best_model = max(model_scores, key=lambda k: model_scores[k][0])
print('----------------------------------------------------------------')
print(f"The best performing model is {best_model} with an accuracy of {model_scores[best_model][0]:.2f} ")
# Out:
# SVM Accuracy: 0.80 (+/- 0.01)
# Random Forest Accuracy: 0.89 (+/- 0.02)
# Gradient Boosting Accuracy: 0.89 (+/- 0.02)
# ----------------------------------------------------------------
# The best performing model is Gradient Boosting with an accuracy of 0.89

# %% [markdown]
# *    Fine-tune hyperparameters of the selected models to optimize performance.

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import GradientBoostingClassifier

# Create Gradient Boosting Classifier
gb_clf = GradientBoostingClassifier()

# Hyperparameters to tune
param_grid = {
    'n_estimators': [100, 200],
    'learning_rate': [0.05, 0.1],
    'max_depth': [3, 5]
}
# Create the GridSearchCV object
grid_search = GridSearchCV(gb_clf, param_grid, cv=5, verbose=0)
grid_search.fit(X_train, y_train)

best_rf_scores = cross_val_score(gb_clf, X_scaled, y_train, cv=5)
b=np.mean(best_rf_scores)
print(f"Tuned model Accuracy: {np.mean(best_rf_scores):.2f} (+/- {np.std(best_rf_scores) * 2:.2f})")
print("Best parameters:", grid_search.best_params_)
# Out:
# Tuned model Accuracy: 0.89 (+/- 0.02)
# Best parameters: {'learning_rate': 0.05, 'max_depth': 5, 'n_estimators': 100}

# %%
    scoring = ['accuracy', 'precision', 'recall', 'f1']
    scores = cross_validate(grid_search, X_train, y_train, scoring=scoring, cv=5)
    print("Cross-Validation Scores:")


    cv_results = pd.DataFrame(scores)
    table = tabulate(cv_results, headers=['Fit_time', 'Score_time', 'Test_accuracy', 'Test_precision', 'Test_recall', 'Test_f1'], tablefmt='grid')
    colored_tableM = table.replace('-', Fore.BLUE + '-')
    print(colored_tableM)
    avg_accuracy = scores['test_accuracy'].mean()
    avg_f1 = scores['test_f1'].mean()  # Calculate average F1 score
    print("Average test accuracy:", avg_accuracy)
    print("Average F1 score:", avg_f1)
# Out:
# Cross-Validation Scores:
# +----+------------+--------------+-----------------+------------------+---------------+-----------+
# |    |   Fit_time |   Score_time |   Test_accuracy |   Test_precision |   Test_recall |   Test_f1 |
# +====+============+==============+=================+==================+===============+===========+
# |  0 |    281.158 |    0.0111201 |        0.89771  |         0.737179 |      0.552885 |  0.631868 |
# +----+------------+--------------+-----------------+------------------+---------------+-----------+
# |  1 |    284.504 |    0.0109675 |        0.903817 |         0.715789 |      0.653846 |  0.683417 |
# +----+------------+--------------+-----------------+------------------+---------------+-----------+
# |  2 |    287.037 |    0.0115414 |        0.880916 |         0.638298 |      0.576923 |  0.606061 |
# +----+------------+--------------+-----------------+------------------+---------------+-----------+
# ...

# %% [markdown]
# *    Explore feature engineering techniques to extract more meaningful insights from the
# data.

# %%
train_data.drop(['Student ID', 'Program ID'], axis=1)
test_data.drop(['Student ID', 'Program ID'], axis=1)
# Out:
#       Age Gender   Home Region Home City Program Main Category Code  \
# 0    23.0   أنثى  منطقة الرياض    الرياض                       CAUF
# 1    31.0   أنثى  منطقة الرياض    الرياض                       PCRF
# 2    29.0   أنثى  منطقة الرياض    الرياض                       CAUF
# 3    23.0   أنثى  منطقة الرياض    الرياض                       PCRF
# 4    30.0   أنثى  منطقة الرياض    الرياض                       TOSL
# ..    ...    ...           ...       ...                        ...
# 813  36.0    ذكر  منطقة الرياض    الرياض                       GRST
# 814  29.0    ذكر  منطقة الرياض    الرياض                       CAUF
# 815  32.0    ذكر  منطقة الرياض    الرياض                       GRST
# 816  28.0   أنثى  منطقة الرياض    الرياض                       PCRF
# 817  23.0    ذكر  منطقة الرياض    الرياض                       PCRF
#
#     Program Sub Category Code Technology Type Program Skill Level  \
# 0                        SWPS         تقليدية               متوسط
# ...

# %% [markdown]
# # Conclusion

# %% [markdown]
# we conclude that the best algorithm is:
#
# logistical and Gradient Boosting.One of the difficulties we faced was
# that the data had an Arabic part and an English part, and this was solved by converting the English parts to Arabic and the missing data is large .
#
#
#
# *  the best model is Gradient Boosting Classifier
# *  Average test accuracy: 0.8901936680293213
# *  Average F1 score: 0.6313645083518844
